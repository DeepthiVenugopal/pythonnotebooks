# %%
import pandas as pd
from sqlalchemy import create_engine

dbfile = r'datasets/database.sqlite'
engine = create_engine(r"sqlite:///{}".format(dbfile))

#sql="select name from sqlite_master where type='table';"
reviewgenre_sql = 'SELECT genres.reviewid,genre,title,artist,url,score,best_new_music,author,author_type,pub_date,pub_weekday,pub_day,pub_month,pub_year from genres,reviews where genres.reviewid = reviews.reviewid;'
df_reviewgenre = pd.read_sql(reviewgenre_sql,engine)
genresql = 'select * from genres;'
df_genre = pd.read_sql(genresql,engine)
df_reviewgenre
df_genre
# Out:
#        reviewid         genre
# 0         22703    electronic
# 1         22721         metal
# 2         22659          rock
# 3         22661          rock
# 4         22725    electronic
# 5         22722          None
# 6         22704           rap
# 7         22694    electronic
# 8         22714  experimental
# 9         22724           rap
# 10        22715  experimental
# 11        22745           rap
# 12        22700    electronic
# 13        22720           rap
# 14        22699           rap
# 15        22665          None
# 16        22666  experimental
# 17        22719           rap
# 18        22719       pop/r&b
# 19        22667  experimental
# 20        22691           rap
# 21        22691       pop/r&b
# 22        22702         metal
# 23        22718          rock
# 24        22706  experimental
# 25        22695          rock
# 26        22695  experimental
# 27        22713    electronic
# 28        22705  folk/country
# 29        22532          rock
# ...

# %%
df_reviewgenre[df_reviewgenre.duplicated()==True].sort_values(by='reviewid')
# Out:
#        reviewid   genre                         title               artist  \
# 14627      9417  global                    radiodread  easy star all-stars
# 14636      9417  global                    radiodread  easy star all-stars
# 14637      9417  global                    radiodread  easy star all-stars
# 14633      9460    rock           subliminal genocide              xasthur
# 14635      9460   metal           subliminal genocide              xasthur
# 14642      9460    rock           subliminal genocide              xasthur
# 14643      9460    rock           subliminal genocide              xasthur
# 14644      9460   metal           subliminal genocide              xasthur
# 14645      9460   metal           subliminal genocide              xasthur
# 14631      9499    None                young machetes   the blood brothers
# 14640      9499    None                young machetes   the blood brothers
# ...

# %%
df_genre[df_genre['reviewid']==9460]
# Out:
#        reviewid  genre
# 14629      9460   rock
# 14630      9460  metal
# 14634      9460   rock
# 14635      9460  metal

# %%
df_genre[df_genre.duplicated()==True]
# Out:
#        reviewid   genre
# 14631      9417  global
# 14632      9505    None
# 14633      9499    None
# 14634      9460    rock
# 14635      9460   metal

# %%
df_genre[(df_genre.groupby('reviewid')['genre'].count())]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-6684493e7fe5> in <module>()
# ----> 1 df_genre[(df_genre.groupby('reviewid')['genre'].count())]
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
# ...

# %%
#dfgenredupes = pd.DataFrame(df_genre.groupby('reviewid')['genre'].count())
dfdupegenres =df_genre.groupby('reviewid').size().reset_index()
dfdupegenres.rename(columns={0:'frequency'},inplace = True)
dfdupegenres
# Out:
#        reviewid  frequency
# 0             1          1
# 1             6          1
# 2             7          1
# 3             8          1
# 4            10          1
# 5            11          1
# 6            12          2
# 7            15          2
# 8            16          2
# 9            17          2
# 10           18          2
# 11           19          2
# 12           20          2
# 13           21          2
# 14           22          2
# 15           23          2
# 16           24          2
# 17           25          2
# 18           31          1
# 19           32          1
# 20           33          1
# 21           36          1
# 22           39          1
# 23           40          1
# 24           41          1
# 25           42          1
# 26           43          1
# 27           44          1
# 28           47          2
# 29           50          2
# ...         ...        ...
# 18359     22691          2
# 18360     22692          1
# ...
