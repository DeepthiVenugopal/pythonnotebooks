# %%
import pandas as pd
from sqlalchemy import create_engine

dbfile = r'datasets/database.sqlite'
engine = create_engine(r"sqlite:///{}".format(dbfile))

#sql="select name from sqlite_master where type='table';"
sql = 'SELECT * from reviews'
df = pd.read_sql(sql,engine)
df.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# ...

# %%
df
# Out:
#        reviewid                                              title  \
# 0         22703                                          mezzanine
# 1         22721                                       prelapsarian
# 2         22659                               all of them naturals
# 3         22661                                        first songs
# 4         22725                                          new start
# 5         22722      insecure (music from the hbo original series)
# 6         22704                            stillness in wonderland
# 7         22694                                           tehillim
# 8         22714                                         reflection
# 9         22724                       filthy america its beautiful
# 10        22715                              clear sounds/perfetta
# 11        22745                                   run the jewels 3
# 12        22700                                              nadir
# ...

# %%
df[df['best_new_music'] ==1]
# Out:
#        reviewid                                            title  \
# 3         22661                                      first songs
# 11        22745                                 run the jewels 3
# 28        22707           swiss radio days vol. 41 - zurich 1961
# 50        22663                        the early years 1965-1972
# 56        22593              bobo yy: belle poque in upper volta
# 58        22555                                              box
# 75        22393              unfinished music no. 1: two virgins
# 79        22639                                          singles
# 99        22467                                  before the dawn
# 117       22592                                       incunabula
# 131       22607  we got it from here... thank you 4 your service
# 135       22401     washington phillips and his manzarene dreams
# 143       22527                     the complete sony recordings
# ...

# %%
df[df['artist']=='pink floyd']
# Out:
#        reviewid                                              title  \
# 50        22663                          the early years 1965-1972
# 2514      20006                                  the endless river
# 10691     10968                                     oh, by the way
# 10977     10643  the piper at the gates of dawn  [40th annivers...
# 18071      6307                                            animals
#
#            artist                                                url  score  \
# 50     pink floyd  http://pitchfork.com/reviews/albums/22663-the-...    8.8
# 2514   pink floyd  http://pitchfork.com/reviews/albums/20006-pink...    5.7
# 10691  pink floyd  http://pitchfork.com/reviews/albums/10968-oh-b...    4.0
# 10977  pink floyd  http://pitchfork.com/reviews/albums/10643-the-...    9.4
# 18071  pink floyd  http://pitchfork.com/reviews/albums/6307-animals/   10.0
#
#        best_new_music              author  author_type    pub_date  \
# ...

# %%
df.groupby('pub_month').agg({'reviewid':'count','best_new_music':'sum', 'score':['sum','mean']})
# Out:
#           reviewid    score           best_new_music
#              count      sum      mean          count
# pub_month
# 1             1528  10710.4  7.009424           1528
# 2             1534  10715.4  6.985267           1534
# 3             1697  11848.1  6.981791           1697
# 4             1627  11296.4  6.943085           1627
# 5             1616  11368.8  7.035149           1616
# 6             1639  11423.9  6.970043           1639
# 7             1521  10579.2  6.955424           1521
# 8             1515  10565.0  6.973597           1515
# 9             1615  11362.0  7.035294           1615
# 10            1768  12525.5  7.084559           1768
# 11            1514  10664.0  7.043593           1514
# 12             819   5798.6  7.080098            819

# %%
df.groupby('pub_weekday').agg({'reviewid':'count','best_new_music':'sum', 'score':['sum','mean']})
# Out:
#             reviewid    score           best_new_music
#                count      sum      mean            sum
# pub_weekday
# 0               3520  24730.2  7.025625            214
# 1               4086  28625.3  7.005702            199
# 2               3580  24928.7  6.963324            154
# 3               3518  24592.3  6.990421            170
# 4               2507  17659.2  7.043957            170
# 5                175   1269.2  7.252571              9
# 6               1007   7052.4  7.003376             27

# %%
df.corr()
# Out:
#                 reviewid     score  best_new_music  pub_weekday   pub_day  \
# reviewid        1.000000  0.036345        0.092847    -0.037202 -0.017858
# score           0.036345  1.000000        0.300219     0.003029 -0.006455
# best_new_music  0.092847  0.300219        1.000000    -0.012427 -0.000503
# pub_weekday    -0.037202  0.003029       -0.012427     1.000000  0.003803
# pub_day        -0.017858 -0.006455       -0.000503     0.003803  1.000000
# pub_month       0.033097  0.019690        0.011640     0.006871 -0.088532
# pub_year        0.942696  0.045186        0.101688    -0.019879 -0.029944
#
#                 pub_month  pub_year
# reviewid         0.033097  0.942696
# score            0.019690  0.045186
# best_new_music   0.011640  0.101688
# pub_weekday      0.006871 -0.019879
# pub_day         -0.088532 -0.029944
# pub_month        1.000000 -0.031909
# pub_year        -0.031909  1.000000

# %%
df.groupby('pub_weekday')['reviewid'].count()
# Out:
# pub_weekday
# 0    3520
# 1    4086
# 2    3580
# 3    3518
# 4    2507
# 5     175
# 6    1007
# Name: reviewid, dtype: int64

# %%
df.groupby('pub_month')['reviewid'].count()
# Out:
# pub_month
# 1     1528
# 2     1534
# 3     1697
# 4     1627
# 5     1616
# 6     1639
# 7     1521
# 8     1515
# 9     1615
# 10    1768
# 11    1514
# 12     819
# Name: reviewid, dtype: int64

# %%
df_artistlist = df.groupby('artist')['reviewid'].count()
df_artistlist.sort_values(ascending= False,inplace = True)
df_artistlist.head()
# Out:
# artist
# various artists     688
# guided by voices     23
# the beatles          21
# david bowie          21
# of montreal          20
# Name: reviewid, dtype: int64

# %%
df_nartistlist = df[df['artist'] != 'various artists']

# %%
df[df['artist'] == 'various artists']
